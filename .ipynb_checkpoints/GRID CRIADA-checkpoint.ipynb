# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import mplfinance as mpf
from finta import TA
import work as wk

# %% [markdown]
# # LOAD DATA-

# %%
def map_strin_date(x):
    return datetime.strptime(x, "%Y-%m-%d %H:%M:%S")

# %%
df_criado = pd.read_csv("saida_xrp.csv")
df_criado.head()
# Out:
#                   date                  fim     open    close       volume  \
# 0  2020-10-01 00:28:59  2020-10-01 00:33:59  1.36278  1.36278     8.000000
# 1  2020-10-01 00:43:59  2020-10-01 00:48:59  1.36361  1.36361    49.000000
# 2  2020-10-01 00:53:59  2020-10-01 00:58:59  1.36844  1.35750  4260.364038
# 3  2020-10-01 01:03:59  2020-10-01 01:08:59  1.36000  1.36000     2.000000
# 4  2020-10-01 01:08:59  2020-10-01 01:13:59  1.36000  1.36000     1.000000
#
#       high      low
# 0  1.36278  1.36278
# 1  1.36361  1.36361
# 2  1.36844  1.35750
# 3  1.36000  1.36000
# 4  1.36000  1.36000

# %%
df_criado["date"] = df_criado["date"].map(map_strin_date)

# %%
df_criado.set_index('date', inplace=True)
df_criado.head()
# Out:
#                                      fim     open    close       volume  \
# date
# 2020-10-01 00:28:59  2020-10-01 00:33:59  1.36278  1.36278     8.000000
# 2020-10-01 00:43:59  2020-10-01 00:48:59  1.36361  1.36361    49.000000
# 2020-10-01 00:53:59  2020-10-01 00:58:59  1.36844  1.35750  4260.364038
# 2020-10-01 01:03:59  2020-10-01 01:08:59  1.36000  1.36000     2.000000
# 2020-10-01 01:08:59  2020-10-01 01:13:59  1.36000  1.36000     1.000000
#
#                         high      low
# date
# 2020-10-01 00:28:59  1.36278  1.36278
# 2020-10-01 00:43:59  1.36361  1.36361
# 2020-10-01 00:53:59  1.36844  1.35750
# 2020-10-01 01:03:59  1.36000  1.36000
# 2020-10-01 01:08:59  1.36000  1.36000

# %% [markdown]
# # Construindo a estrategia

# %%
## pre processando e construindo descritores

# %%
df_criado["ema_30"] =  TA.EMA(df_criado, 30)
df_criado["ema_100"] =  TA.EMA(df_criado, 100)
df_criado["ema_300"] =  TA.EMA(df_criado, 400)
df_criado["ema_1200"] =  TA.EMA(df_criado, 1200)
saida_BB =  TA.BBANDS(df_criado)
df_criado["BB_UPPER"] =  saida_BB["BB_UPPER"]
df_criado["BB_LOWER"] =  saida_BB["BB_LOWER"]
df_criado["distancia_BB"] = saida_BB["BB_UPPER"] - saida_BB["BB_LOWER"]
df_criado["normaliza"] = df_criado["close"] - df_criado["ema_1200"]
# df_criado["r_compra"], df_criado["r_venda"], df_criado["libera_trade"] = calcula_r_compra_venda(df_criado)
df_criado.head()
# Out:
#                                      fim     open    close       volume  \
# date
# 2020-10-01 00:28:59  2020-10-01 00:33:59  1.36278  1.36278     8.000000
# 2020-10-01 00:43:59  2020-10-01 00:48:59  1.36361  1.36361    49.000000
# 2020-10-01 00:53:59  2020-10-01 00:58:59  1.36844  1.35750  4260.364038
# 2020-10-01 01:03:59  2020-10-01 01:08:59  1.36000  1.36000     2.000000
# 2020-10-01 01:08:59  2020-10-01 01:13:59  1.36000  1.36000     1.000000
#
#                         high      low    ema_30   ema_100   ema_300  ema_1200  \
# date
# 2020-10-01 00:28:59  1.36278  1.36278  1.362780  1.362780  1.362780  1.362780
# 2020-10-01 00:43:59  1.36361  1.36361  1.363209  1.363199  1.363196  1.363195
# 2020-10-01 00:53:59  1.36844  1.35750  1.361178  1.361261  1.361288  1.361294
# 2020-10-01 01:03:59  1.36000  1.36000  1.360853  1.360936  1.360963  1.360969
# 2020-10-01 01:08:59  1.36000  1.36000  1.360659  1.360742  1.360769  1.360775
#
#                      BB_UPPER  BB_LOWER  distancia_BB  normaliza
# date
# 2020-10-01 00:28:59       NaN       NaN           NaN   0.000000
# 2020-10-01 00:43:59       NaN       NaN           NaN   0.000415
# 2020-10-01 00:53:59       NaN       NaN           NaN  -0.003794
# 2020-10-01 01:03:59       NaN       NaN           NaN  -0.000969
# 2020-10-01 01:08:59       NaN       NaN           NaN  -0.000775

# %% [markdown]
# # Visualizando os dados

# %%
# quant = 100
# gap = 9000 + quant
inicio = 10000
fim = 15000 + inicio


# df_bb_uper_n  = saida_BB["BB_UPPER"] 
# df_bb_lower_n = saida_BB["BB_LOWER"] 


fig, ax = plt.subplots(1,1)
fig.set_size_inches(18.5, 30.5)


ax.plot(df_criado["close"][-fim:-inicio],label='Close')
# ax[0].plot(df_criado["ema_30"][-fim:-inicio],label='30')
# ax[0].plot(df_criado["ema_100"][-fim:-inicio],label='100')
# ax[0].plot(df_criado["ema_300"][-fim:-inicio],label='300')
# ax[0].plot(df_criado["ema_1200"][-fim:-inicio],label='1200')
# ax[0].plot(df_criado["BB_UPPER"][-fim:-inicio], label ="boiler")
# ax[0].plot(df_criado["BB_LOWER"][-fim:-inicio], label ="boiler")

# ax[0].legend()

# ax[1].plot(df_criado["normaliza"][-fim:-inicio],label='dif_300')
# ax[2].plot(df_criado["r_compra"][-fim:-inicio], label="compra")
# ax[2].plot( df_criado["r_venda"][-fim:-inicio], label="venda")
# # ax[2].plot(r_liberado_operacao[-fim:-inicio], label="indeciso")
# ax[3].plot(df_criado["distancia_BB"][-fim:-inicio], label="venda")
# ax[2].legend()
plt.savefig("oi.jpg")
plt.show()

# %%
# Out:
# 0.93

# %% [markdown]
# # Estrategia
#  - quando estiver em compra e liberado o objetivo é ficar com  90%- 10% da conta em btc e isso deve ocorrer no menor valor
# - quando estiver em venda e liberado o objetivo é ficar com 10%-90% da conta em btc  e isso deve ocorrer no maior valor
# -tem que vender acida do valor médio da compra

# %%
def constroi_ordem(negociado_compra, porcentagem, coin="XRP"):
    dic_ordem_criada = {"coin": coin,
                        "qnt": 0.2,
                        "compra": negociado_compra,
                        "venda": negociado_compra + porcentagem,
                        "fee_total": 0,
                        "lucro": 0,
                         "estado": "aberta"}
    
    return dic_ordem_criada

# %%
def constroi_grid_estatico(valor_base, variacao_grid):
    def aciona_valor(valor_atual):
        variacao_preco = valor_atual - valor_base
        r_gatilho_constori_nova_operacao = (variacao_preco % variacao_grid >= 0) & (variacao_preco % variacao_grid <= 0.01)
        return r_gatilho_constori_nova_operacao
    return aciona_valor

# %%
map_valor_aciona_operacao = constroi_grid_estatico(1, 0.3) #0.2 reais

# %%
df_criado["aciona"] = df_criado["close"].map(map_valor_aciona_operacao)

# %%
df_selecao_gatilho = df_criado.where(df_criado["aciona"]==True).dropna()]
plt.scatter(df_selecao_gatilho.index,df_selecao_gatilho["close"])
# list(filter(lambda x: x==True,df_criado["aciona"]))

# %%
def gerador_dados(df_criado):
    for row in df_criado.iterrows():
        yield row

# %%
class Mercador_back_test_grid():
    def __init__(self, qnt_dinheiro, distancia):
        self.qnt_dinehiro_inicial = qnt_dinheiro 
        self.qnt_dinheiro_atual = qnt_dinheiro
        self.ordens = []
        self.distancia = distancia
    
    def _compra(self, ordem):
        self.qnt_dinheiro_atual = self.qnt_dinheiro_atual - ordem["compra"] * ordem["qnt"]
        self.ordens.append(ordem)
        
    def cria_ordens(self, valor_compra):
        ordem = constroi_ordem(valor_compra, self.distancia)
        self._compra(ordem)
        
    def _termina_ordens(self,close, lis_ordens_a_serem_executadas):
        for ordem in lis_ordens_a_serem_executadas:
            ordem["estado"] = "fechada"
            ordem["lucro"] = ordem["compra"] - close
            self.qnt_dinheiro_atual = self.qnt_dinheiro_atual + ordem["lucro"]
                
    def executa_ordens(self, close):
        def get_ordens_abertas(x):
            return x["estado"] == "aberta"
        
        lis_ordens_aberta = list(filter(get_ordens_abertas, self.ordens))
        r_existe_ordens_abertas = len(lis_ordens_aberta) == 0
        if r_existe_ordens_abertas:
            def get_ordens_abertas_range(x):
                return x["venda"] > close
            
            lis_ordens_a_serem_executadas = list(filter(get_ordens_abertas_range),lis_ordens_aberta)
            self._termina_ordens(close,lis_ordens_a_serem_executadas)

# %%
def back_test():
    g1 = gerador_dados(df_criado)
    m1 = Mercador_back_test_grid(100, 0.3) #0.3 centavos
    for tempo, linha in g1:
    #     tempo, linha = next(g1)
        r_aciona = linha["aciona"]

        if r_aciona:
            m1.cria_ordens(linha["close"])
            m1.executa_ordens(linha["close"])
    return m1

# %%
m1 = back_test()

# %%
m1.ordens
# Out:
# [{'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3627799999999999,
#   'venda': 1.66278,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36361,
#   'venda': 1.66361,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3575,
#   'venda': 1.6575,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3571,
#   'venda': 1.6571,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.354,
#   'venda': 1.6540000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.354,
#   'venda': 1.6540000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.354,
#   'venda': 1.6540000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3559999999999999,
#   'venda': 1.656,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3555,
#   'venda': 1.6555,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3557,
#   'venda': 1.6557,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3556,
#   'venda': 1.6556,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3556,
#   'venda': 1.6556,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3557,
#   'venda': 1.6557,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3557,
#   'venda': 1.6557,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3558,
#   'venda': 1.6558,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3559999999999999,
#   'venda': 1.656,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3559999999999999,
#   'venda': 1.656,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35611,
#   'venda': 1.65611,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36171,
#   'venda': 1.66171,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3658,
#   'venda': 1.6658,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3658,
#   'venda': 1.6658,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3659999999999999,
#   'venda': 1.666,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36711,
#   'venda': 1.66711,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36853,
#   'venda': 1.66853,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36216,
#   'venda': 1.66216,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3624,
#   'venda': 1.6624,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.37,
#   'venda': 1.6700000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3627799999999999,
#   'venda': 1.66278,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3671799999999998,
#   'venda': 1.6671799999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36791,
#   'venda': 1.66791,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36937,
#   'venda': 1.66937,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3606200000000002,
#   'venda': 1.6606200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36679,
#   'venda': 1.66679,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36017,
#   'venda': 1.6601700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3678,
#   'venda': 1.6678,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36058,
#   'venda': 1.66058,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36775,
#   'venda': 1.66775,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36094,
#   'venda': 1.66094,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3678,
#   'venda': 1.6678,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36055,
#   'venda': 1.66055,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3666399999999999,
#   'venda': 1.66664,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36673,
#   'venda': 1.66673,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3512,
#   'venda': 1.6512,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35551,
#   'venda': 1.65551,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3499,
#   'venda': 1.6499000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35638,
#   'venda': 1.65638,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.345,
#   'venda': 1.645,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34851,
#   'venda': 1.6485100000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34597,
#   'venda': 1.6459700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34423,
#   'venda': 1.64423,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34697,
#   'venda': 1.64697,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34687,
#   'venda': 1.64687,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3413899999999999,
#   'venda': 1.64139,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34216,
#   'venda': 1.64216,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34038,
#   'venda': 1.64038,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34807,
#   'venda': 1.6480700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3471899999999999,
#   'venda': 1.64719,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3497,
#   'venda': 1.6497,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3503,
#   'venda': 1.6503,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35581,
#   'venda': 1.65581,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3444,
#   'venda': 1.6444,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3405799999999999,
#   'venda': 1.64058,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3403399999999999,
#   'venda': 1.64034,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3538700000000001,
#   'venda': 1.6538700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34389,
#   'venda': 1.64389,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3603100000000001,
#   'venda': 1.6603100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35001,
#   'venda': 1.65001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35999,
#   'venda': 1.65999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35253,
#   'venda': 1.65253,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35405,
#   'venda': 1.65405,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35419,
#   'venda': 1.65419,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3501100000000001,
#   'venda': 1.6501100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3547799999999999,
#   'venda': 1.65478,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35935,
#   'venda': 1.65935,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35974,
#   'venda': 1.65974,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3501,
#   'venda': 1.6501000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36005,
#   'venda': 1.66005,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35891,
#   'venda': 1.65891,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3501,
#   'venda': 1.6501000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3501,
#   'venda': 1.6501000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3633899999999999,
#   'venda': 1.66339,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35258,
#   'venda': 1.65258,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.359,
#   'venda': 1.659,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35016,
#   'venda': 1.65016,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.358,
#   'venda': 1.6580000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35025,
#   'venda': 1.65025,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35495,
#   'venda': 1.6549500000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35494,
#   'venda': 1.65494,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3651,
#   'venda': 1.6651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35556,
#   'venda': 1.6555600000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35995,
#   'venda': 1.65995,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3546,
#   'venda': 1.6546,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35995,
#   'venda': 1.65995,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3596700000000002,
#   'venda': 1.6596700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35961,
#   'venda': 1.65961,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502100000000001,
#   'venda': 1.6502100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3591799999999998,
#   'venda': 1.6591799999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35909,
#   'venda': 1.65909,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35931,
#   'venda': 1.65931,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35025,
#   'venda': 1.65025,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35022,
#   'venda': 1.65022,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35037,
#   'venda': 1.6503700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35664,
#   'venda': 1.6566400000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35695,
#   'venda': 1.6569500000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3598299999999999,
#   'venda': 1.65983,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35857,
#   'venda': 1.65857,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3587,
#   'venda': 1.6587,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35153,
#   'venda': 1.65153,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3598700000000001,
#   'venda': 1.6598700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35985,
#   'venda': 1.65985,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35039,
#   'venda': 1.65039,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35022,
#   'venda': 1.65022,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3561299999999998,
#   'venda': 1.6561299999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3561299999999998,
#   'venda': 1.6561299999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35822,
#   'venda': 1.65822,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35963,
#   'venda': 1.65963,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35105,
#   'venda': 1.6510500000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3502,
#   'venda': 1.6502000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.351,
#   'venda': 1.651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.351,
#   'venda': 1.651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.351,
#   'venda': 1.651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.351,
#   'venda': 1.651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.351,
#   'venda': 1.651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.351,
#   'venda': 1.651,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35103,
#   'venda': 1.65103,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3594,
#   'venda': 1.6594,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35999,
#   'venda': 1.65999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35352,
#   'venda': 1.65352,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35067,
#   'venda': 1.65067,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3352,
#   'venda': 1.6352,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33551,
#   'venda': 1.63551,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.30121,
#   'venda': 1.60121,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.30607,
#   'venda': 1.60607,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31879,
#   'venda': 1.61879,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33178,
#   'venda': 1.63178,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3391600000000001,
#   'venda': 1.6391600000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3244,
#   'venda': 1.6244,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32007,
#   'venda': 1.6200700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33627,
#   'venda': 1.6362700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3567799999999999,
#   'venda': 1.65678,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3252,
#   'venda': 1.6252,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32831,
#   'venda': 1.6283100000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32564,
#   'venda': 1.62564,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31951,
#   'venda': 1.61951,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3194700000000001,
#   'venda': 1.6194700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31734,
#   'venda': 1.61734,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31149,
#   'venda': 1.61149,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31821,
#   'venda': 1.6182100000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31007,
#   'venda': 1.6100700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31771,
#   'venda': 1.61771,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3189799999999998,
#   'venda': 1.6189799999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3188,
#   'venda': 1.6188,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3196700000000001,
#   'venda': 1.6196700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31989,
#   'venda': 1.61989,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31999,
#   'venda': 1.61999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31999,
#   'venda': 1.61999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.30121,
#   'venda': 1.60121,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3188,
#   'venda': 1.6188,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31995,
#   'venda': 1.61995,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.31989,
#   'venda': 1.61989,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.318,
#   'venda': 1.618,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3198,
#   'venda': 1.6198000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3122200000000002,
#   'venda': 1.6122200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32656,
#   'venda': 1.62656,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33759,
#   'venda': 1.63759,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.328,
#   'venda': 1.6280000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3231600000000001,
#   'venda': 1.6231600000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3368200000000001,
#   'venda': 1.6368200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32854,
#   'venda': 1.62854,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32,
#   'venda': 1.62,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33057,
#   'venda': 1.63057,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3381,
#   'venda': 1.6381000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3346,
#   'venda': 1.6346,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3392,
#   'venda': 1.6392,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3279100000000001,
#   'venda': 1.6279100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32732,
#   'venda': 1.62732,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34081,
#   'venda': 1.64081,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3384200000000002,
#   'venda': 1.6384200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33748,
#   'venda': 1.63748,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33982,
#   'venda': 1.63982,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32704,
#   'venda': 1.62704,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33366,
#   'venda': 1.6336600000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3338,
#   'venda': 1.6338000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3343,
#   'venda': 1.6343,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.32125,
#   'venda': 1.62125,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33354,
#   'venda': 1.63354,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3347,
#   'venda': 1.6347,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33396,
#   'venda': 1.63396,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33464,
#   'venda': 1.63464,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33499,
#   'venda': 1.63499,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3300100000000001,
#   'venda': 1.6300100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3375299999999999,
#   'venda': 1.63753,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33905,
#   'venda': 1.6390500000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33918,
#   'venda': 1.63918,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3352,
#   'venda': 1.6352,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34198,
#   'venda': 1.64198,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33648,
#   'venda': 1.63648,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34048,
#   'venda': 1.64048,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3301100000000001,
#   'venda': 1.6301100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33092,
#   'venda': 1.6309200000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33896,
#   'venda': 1.63896,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34198,
#   'venda': 1.64198,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33971,
#   'venda': 1.63971,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33899,
#   'venda': 1.63899,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3352,
#   'venda': 1.6352,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3399,
#   'venda': 1.6399000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3307200000000001,
#   'venda': 1.6307200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33724,
#   'venda': 1.63724,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3388799999999998,
#   'venda': 1.63888,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33192,
#   'venda': 1.63192,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3327,
#   'venda': 1.6327,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33636,
#   'venda': 1.63636,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33968,
#   'venda': 1.63968,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33844,
#   'venda': 1.6384400000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3309799999999998,
#   'venda': 1.6309799999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3309799999999998,
#   'venda': 1.6309799999999999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33523,
#   'venda': 1.63523,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33114,
#   'venda': 1.63114,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3301,
#   'venda': 1.6301,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33292,
#   'venda': 1.6329200000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33005,
#   'venda': 1.63005,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3366799999999999,
#   'venda': 1.63668,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33349,
#   'venda': 1.63349,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3366,
#   'venda': 1.6366,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33699,
#   'venda': 1.63699,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33684,
#   'venda': 1.63684,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33586,
#   'venda': 1.63586,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33699,
#   'venda': 1.63699,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33523,
#   'venda': 1.63523,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33595,
#   'venda': 1.63595,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3363200000000002,
#   'venda': 1.6363200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33055,
#   'venda': 1.63055,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33866,
#   'venda': 1.63866,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3391600000000001,
#   'venda': 1.6391600000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33259,
#   'venda': 1.63259,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33837,
#   'venda': 1.63837,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33217,
#   'venda': 1.6321700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33844,
#   'venda': 1.6384400000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3388,
#   'venda': 1.6388,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33,
#   'venda': 1.6300000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3386799999999999,
#   'venda': 1.63868,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33091,
#   'venda': 1.63091,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33091,
#   'venda': 1.63091,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3311600000000001,
#   'venda': 1.6311600000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3311600000000001,
#   'venda': 1.6311600000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3382,
#   'venda': 1.6382,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33619,
#   'venda': 1.63619,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33766,
#   'venda': 1.6376600000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33694,
#   'venda': 1.63694,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.331,
#   'venda': 1.631,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.331,
#   'venda': 1.631,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.331,
#   'venda': 1.631,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33996,
#   'venda': 1.63996,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33879,
#   'venda': 1.63879,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33999,
#   'venda': 1.63999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3351,
#   'venda': 1.6351,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33499,
#   'venda': 1.63499,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3412,
#   'venda': 1.6412,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34398,
#   'venda': 1.64398,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3412,
#   'venda': 1.6412,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.344,
#   'venda': 1.6440000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.33531,
#   'venda': 1.63531,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34,
#   'venda': 1.6400000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.36,
#   'venda': 1.6600000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34028,
#   'venda': 1.64028,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3444,
#   'venda': 1.6444,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35791,
#   'venda': 1.65791,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34038,
#   'venda': 1.64038,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35341,
#   'venda': 1.65341,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34216,
#   'venda': 1.64216,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3400100000000001,
#   'venda': 1.6400100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34517,
#   'venda': 1.64517,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.34025,
#   'venda': 1.64025,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.35,
#   'venda': 1.6500000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.348,
#   'venda': 1.6480000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.348,
#   'venda': 1.6480000000000001,
#   'fee_total': 0,
# ...
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3940000000000001,
#   'venda': 1.6940000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39378,
#   'venda': 1.69378,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3941299999999999,
#   'venda': 1.69413,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39371,
#   'venda': 1.69371,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3997899999999999,
#   'venda': 1.69979,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39371,
#   'venda': 1.69371,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3938,
#   'venda': 1.6938,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39011,
#   'venda': 1.69011,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3995,
#   'venda': 1.6995,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39001,
#   'venda': 1.69001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39001,
#   'venda': 1.69001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39767,
#   'venda': 1.69767,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39218,
#   'venda': 1.69218,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3940000000000001,
#   'venda': 1.6940000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.399,
#   'venda': 1.699,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39055,
#   'venda': 1.69055,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39055,
#   'venda': 1.69055,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3979,
#   'venda': 1.6979,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.395,
#   'venda': 1.695,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3979,
#   'venda': 1.6979,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3979,
#   'venda': 1.6979,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.396,
#   'venda': 1.696,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3979,
#   'venda': 1.6979,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39999,
#   'venda': 1.6999900000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39999,
#   'venda': 1.6999900000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.396,
#   'venda': 1.696,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.392,
#   'venda': 1.692,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39946,
#   'venda': 1.69946,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3927100000000001,
#   'venda': 1.6927100000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39285,
#   'venda': 1.69285,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.392,
#   'venda': 1.692,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3926,
#   'venda': 1.6926,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39412,
#   'venda': 1.69412,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39446,
#   'venda': 1.69446,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39771,
#   'venda': 1.69771,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3988,
#   'venda': 1.6988,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39301,
#   'venda': 1.6930100000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3999,
#   'venda': 1.6999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39981,
#   'venda': 1.69981,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3976,
#   'venda': 1.6976,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.396,
#   'venda': 1.696,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39,
#   'venda': 1.69,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39,
#   'venda': 1.69,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3991799999999999,
#   'venda': 1.69918,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3992200000000001,
#   'venda': 1.6992200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39612,
#   'venda': 1.69612,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39891,
#   'venda': 1.6989100000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.395,
#   'venda': 1.695,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.396,
#   'venda': 1.696,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3941,
#   'venda': 1.6941,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39978,
#   'venda': 1.69978,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39434,
#   'venda': 1.69434,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39599,
#   'venda': 1.69599,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.395,
#   'venda': 1.695,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3955,
#   'venda': 1.6955,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39999,
#   'venda': 1.6999900000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39999,
#   'venda': 1.6999900000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39801,
#   'venda': 1.69801,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3956,
#   'venda': 1.6956,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.399,
#   'venda': 1.699,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39905,
#   'venda': 1.69905,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.399,
#   'venda': 1.699,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3980000000000001,
#   'venda': 1.6980000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39835,
#   'venda': 1.69835,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.395,
#   'venda': 1.695,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39936,
#   'venda': 1.69936,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3940000000000001,
#   'venda': 1.6940000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39469,
#   'venda': 1.69469,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39405,
#   'venda': 1.69405,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3940000000000001,
#   'venda': 1.6940000000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39401,
#   'venda': 1.69401,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39907,
#   'venda': 1.69907,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39812,
#   'venda': 1.69812,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.4,
#   'venda': 1.7,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39515,
#   'venda': 1.69515,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3999,
#   'venda': 1.6999,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3951,
#   'venda': 1.6951,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.393,
#   'venda': 1.693,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.393,
#   'venda': 1.693,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39693,
#   'venda': 1.69693,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3915,
#   'venda': 1.6915,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3912,
#   'venda': 1.6912,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3912,
#   'venda': 1.6912,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3912200000000001,
#   'venda': 1.6912200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39293,
#   'venda': 1.69293,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3904,
#   'venda': 1.6904000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3904,
#   'venda': 1.6904000000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39667,
#   'venda': 1.6966700000000001,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3906,
#   'venda': 1.6906,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39114,
#   'venda': 1.69114,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.395,
#   'venda': 1.695,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39998,
#   'venda': 1.69998,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39121,
#   'venda': 1.69121,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3993200000000001,
#   'venda': 1.6993200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3998700000000002,
#   'venda': 1.6998700000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3997899999999999,
#   'venda': 1.69979,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39121,
#   'venda': 1.69121,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39767,
#   'venda': 1.69767,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3912200000000001,
#   'venda': 1.6912200000000002,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.3980299999999999,
#   'venda': 1.69803,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  {'coin': 'XRP',
#   'qnt': 0.2,
#   'compra': 1.39121,
#   'venda': 1.69121,
#   'fee_total': 0,
#   'lucro': 0,
#   'estado': 'aberta'},
#  ...]

# %%
# def map_operacoes(linha):
# #     print("----------------------")
# #     print(linha)
#     r_compra = linha["operacao"] == 0
#     r_venda = linha["operacao"] == 1
#     r_c_or_venda = r_compra | r_venda
#     r_schedule =  linha["scheduler"]
#     r_decisao = r_c_or_venda & r_schedule
#     if r_decisao:
#         return 1
#     else:
#         return 0

# %% [markdown]
# # Calculan

# %%
# g1 = gerador_dados(df_criado)

# ls_operacao = []
# ls_qnt_btc = []
# ls_scheduler = []
# vari_menor = -0.3
# varia_maior = 1.5
# tamanho_grid = 0.2

# for saida in g1:
#     ls_operacao.append(estrategia(saida[1],vari_menor, varia_maior )[0])
#     ls_qnt_btc.append(estrategia(saida[1],vari_menor, varia_maior )[1])
#     ls_scheduler.append(scheduler(saida[1],tamanho_grid))
    
# df_criado["operacao"] = ls_operacao
# df_criado["qnt_btc"] = ls_qnt_btc
# df_criado["scheduler"] = ls_scheduler
# df_criado["alguma_operacao"] = df_criado.apply(map_operacoes, axis=1)
# df_criado.head()

# %%
# inicio = 1
# fim = 500 + inicio

# fig, ax = plt.subplots(4,1)
# fig.set_size_inches(18.5, 30.5)

# ax[0].scatter(df_criado.index[-fim:-inicio], df_criado["operacao"][-fim:-inicio])
# ax[1].scatter(df_criado.index[-fim:-inicio], df_criado["qnt_btc"][-fim:-inicio])
# ax[2].scatter(df_criado.index[-fim:-inicio], df_criado["scheduler"][-fim:-inicio])
# ax[3].scatter(df_criado.index[-fim:-inicio], df_criado["alguma_operacao"][-fim:-inicio])

# %%
# class Mercador():
#     def __init__(self, qnt_dinheiro):
#         self.qnt_dinherio_inicial = qnt_dinheiro
#         self.qnt_dinherio_atual = qnt_dinheiro
#         self.btc_atual = 0
#         self.ls_valor_carteira = []
    
#     def _operacao_compra(self, por_para_ajustar, v_negociacao):
#         btc_compra = (self.qnt_dinherio_atual * por_para_ajustar) / v_negociacao
#         self.btc_atual = self.btc_atual + btc_compra
#         self.qnt_dinherio_atual = self.qnt_dinherio_atual * por_para_ajustar
#         self.ls_valor_carteira.append(self.qnt_dinherio_atual + self.btc_atual*v_negociacao )
    
    
#     def _operacao_venda(self, por_para_ajustar, v_negociacao):
#         btc_venda = self.btc_atual * por_para_ajustar
#         self.btc_atual = self.btc_atual - btc_venda
#         self.qnt_dinherio_atual = btc_venda* v_negociacao
    
#         self.ls_valor_carteira.append(self.qnt_dinherio_atual + self.btc_atual*v_negociacao )
    
#     def ajusta_portifolio_por(self, por_para_ajustar, v_negociacao):
#         def get_porcento_atual():
#             s = self.btc_atual * 100/(self.btc_atual + self.qnt_dinherio_atual) # so nao pode ser zero
#             return s 
        
#         r_oper_compra = por_para_ajustar >= get_porcento_atual()
#         r_oper_venda = por_para_ajustar < get_porcento_atual()
#         if r_oper_compra:
#             self._operacao_compra(por_para_ajustar - get_porcento_atual(), v_negociacao)
#         if r_oper_venda:
#             self._operacao_venda(get_porcento_atual() - por_para_ajustar, v_negociacao)
            
# #         print(get_porcento_atual())

# %%
m1 = wk.Mercador_back_teste(100)
df_criado.head()
# Out:
#                                      fim     open    close       volume  \
# date
# 2020-10-01 00:28:59  2020-10-01 00:33:59  1.36278  1.36278     8.000000
# 2020-10-01 00:43:59  2020-10-01 00:48:59  1.36361  1.36361    49.000000
# 2020-10-01 00:53:59  2020-10-01 00:58:59  1.36844  1.35750  4260.364038
# 2020-10-01 01:03:59  2020-10-01 01:08:59  1.36000  1.36000     2.000000
# 2020-10-01 01:08:59  2020-10-01 01:13:59  1.36000  1.36000     1.000000
#
#                         high      low    ema_30   ema_100   ema_300  ema_1200  \
# date
# 2020-10-01 00:28:59  1.36278  1.36278  1.362780  1.362780  1.362780  1.362780
# 2020-10-01 00:43:59  1.36361  1.36361  1.363209  1.363199  1.363196  1.363195
# 2020-10-01 00:53:59  1.36844  1.35750  1.361178  1.361261  1.361288  1.361294
# 2020-10-01 01:03:59  1.36000  1.36000  1.360853  1.360936  1.360963  1.360969
# 2020-10-01 01:08:59  1.36000  1.36000  1.360659  1.360742  1.360769  1.360775
#
#                      BB_UPPER  BB_LOWER  distancia_BB  normaliza  aciona
# date
# 2020-10-01 00:28:59       NaN       NaN           NaN   0.000000    True
# 2020-10-01 00:43:59       NaN       NaN           NaN   0.000415    True
# 2020-10-01 00:53:59       NaN       NaN           NaN  -0.003794    True
# 2020-10-01 01:03:59       NaN       NaN           NaN  -0.000969    True
# 2020-10-01 01:08:59       NaN       NaN           NaN  -0.000775    True

# %%
# g1 = gerador_dados(df_criado)
# m1 = wk.Mercador_back_teste(100)
# for saida in g1:
#     porcentagem = saida[1]["qnt_btc"]
#     r_compra = saida[1]["r_compra"]
#     val_negociacao = saida[1]["close"]
#     r_cheduler = saida[1]["alguma_operacao"] 
#     index = saida[0]
#     r_qnt = porcentagem > 0
#     if r_cheduler:
# #         if r_qnt:
# #         m1.ajusta_portifolio_por(porcentagem, val_negociacao)
# #     if r_qnt:
#         m1.ajusta_portifolio_por(porcentagem, val_negociacao,index, r_compra)

# %%
# def filtra_por(str_operaca):
#     def filt_venda(x):
#         s = x["busc_operacao"] == str_operaca
#         return s
#     return filt_venda
    
# def map_tempo(x):
#     return x["tempo"]
    

# ls_vend= list(map(map_tempo, filter(filtra_por(False), m1.ls_dict)))
# ls_comp = list(map(map_tempo, filter(filtra_por(True), m1.ls_dict)))

# %%
# inicio = 1
# fim = 10000 + inicio

# fig, ax = plt.subplots(3,1)
# fig.set_size_inches(18.5, 30.5)


# # ax[0].plot(df_criado["close"][-fim:-inicio],label='Close')
# # ax[0].plot(df_criado["ema_1200"][-fim:-inicio],label='1200')
# ax[0].scatter(ls_comp, df_criado["close"].loc[ls_comp],label='compra', alpha=0.4)
# ax[0].scatter(ls_vend, df_criado["close"].loc[ls_vend],label='venda', alpha=0.4)
# ax[0].legend()

# ax[1].plot(m1.ls_tempo[-fim:-inicio], m1.ls_valor_carteira[-fim:-inicio])


# ax[1].plot(m1.ls_tempo[-fim:-inicio], m1.ls_valor_carteira[-fim:-inicio])


# ax[2].plot(df_criado["qnt_btc"][-fim:-inicio])

# %%
# m1.ls_tipo[-10:]

# %%
# plt.plot(r_cheduler)
# print(r_cheduler)
# plt.plot(m1.ls_valor_carteira)

# %%
# btc = {"qnt_moeda": 1, "v_negociado":23423, "t_operaca": "buy!sell" }


# class Mercador():
#     def __init__(self, quantidade_inicial, estrategia):
#         self.quantidade_inicial = quantidade_inicial
#         self.quantidade_atual = quantidade_inicial
#         self.btc_comprados_atual = []
#         self.estrategia = estrategia
        
        
#     def novo_tick(self, linha_tabela):
#         estado, qnt_bitcoin_ideal = self.estrategia(linha_tabela)
        
#         r_compra = estado == 0
#         r_venda = estado == 1
#         r_incerto = estado == 2
        
#         if r_compra:
#             self._fazer_operacao_compra(qnt_bitcoin_ideal, linha_tabela["close"])
            
        
#         if r_venda:
#             self._fazer_operacao_compra(qnt_bitcoin_ideal, linha_tabela["close"])
            
#         print(self.btc_comprados_atual)
#         print(self.quantidade_atual)
        
#     def _get_quantidade(self):
#         def map_qnt_btc(x):
#             return x["qnt_moeda"]
        
#         ls_me_com = list(map(map_qnt_btc,self.btc_comprados_atual))
#         r_possui_valore = len(ls_me_com)
#         if r_possui_valore:
#             soma = pd.Series(ls_me_com).sum()
#             return soma
#         else:
#             return 0
    
    

#     def _get_preco_medio_por(self):
#         def map_qnt_btc(x):
#             return x["qnt_moeda"] * x["v_negociado"]
        
#         def get_porcento(soma_btc):
#             s = soma_btc * 100/(soma_btc - self.quantidade_atual) # so nao pode ser zero
#             return s 
        
#         ls_me_com = list(map(map_qnt_btc, self.btc_comprados_atual))
#         r_possui_valore = len(ls_me_com)
#         if r_possui_valore:
            
#             soma_btc = pd.Series(ls_me_com).sum()
#             soma_btc_p =  get_porcento(soma_btc)
#             return soma_btc_p
#         else:
#             return 0

#     def _get_fez_compra(self, preco):
#         def fil_compra(x):
#             r_fez_compra =  preco > x["v_negociado"]*1.02 and preco < x["v_negociado"]*-1.02
#             return r_fez_compra
        
#         r_ja_fez_uma_compra = len(list(filter(fil_compra, self.btc_comprados_atual))) != 0
#         return r_ja_fez_uma_compra
    
#     def _realizar_compra(self, qnt_compra, preco_tick):
#         qnt_compra_2 = qnt_compra/2
#         qnt_compra_brl  = self.quantidade_atual * qnt_compra_2
#         qnt_compra_pedida_moeda = preco_tick/qnt_compra_brl
        
#         self.quantidade_atual = self.quantidade_atual - qnt_compra_brl
        
        
#         self.btc_comprados_atual.append({"qnt_moeda": qnt_compra_pedida_moeda, 
#                                          "v_negociado":preco_tick,
#                                          "t_operaca": "buy" })
        
        
        
#     def _realizar_venda(self, qnt_venda, preco_tick):
#         def map_valores(x):
#             return preco_tick - x["v_negociado"] 
        
#         get_inde_maior = self.btc_comprados_atual.index(max(self.btc_comprados_atual))
#         operacao_aberta = self.btc_comprados_atual[get_inde_maior]
        
#         r_possui_qnt_vender = operacao_aberta["qnt_moeda"] > qnt_venda
#         if r_possui_qnt_vender:
#             self.quantidade_atual = self.quantidade_atual + qnt_venda * preco_tick
#             operacao_aberta["qnt_moeda"] = operacao_aberta["qnt_moeda"] - qnt_venda
            
#         else:
#             self.quantidade_atual = self.quantidade_atual + qnt_venda * preco_tick
#             self.btc_comprados_atual.pop(get_inde_maior)
#             print("_-------------------------------")
#             print(operacao_aberta)
        
    
    
#     def _fazer_operacao_compra(self, qnt_bitcoin_ideal, preco_tick ):
#         qnt_bitcoin_por = self._get_preco_medio_por()
        
#         r_comprar_mais = qnt_bitcoin_por < qnt_bitcoin_ideal
#         r_vender_mais = qnt_bitcoin_por >= qnt_bitcoin_ideal
       
#         if r_comprar_mais:
#             r_ja_fez_uma_compra = self._get_fez_compra(preco_tick)
#             if not r_ja_fez_uma_compra:
#                 self._realizar_compra(qnt_bitcoin_ideal - qnt_bitcoin_por, preco_tick)
                    
#         if r_vender_mais:
#             r_ja_fez_uma_compra = self._get_fez_compra(preco_tick)
#             if not r_ja_fez_uma_compra:
#                 self._realizar_venda(qnt_bitcoin_ideal - qnt_bitcoin_por,preco_tick)

# %%
# Testar uma estrategi

# %%
# def gerador_dados(df_criado):
#     for row in df_criado.iterrows():
#         yield row

# %%
# m1 = Mercador(200, estrategia)
# g1 = gerador_dados(df_criado)

# %%
# m1.novo_tick(next(g1)[1])

# %%
# next(g1)[1]

# %%
# saida_proporção_conta_venda(-13000)

# %%
# na caida mais dinheiro 80-20, total dinheiro mais btc * valor atual

# na subida mais bitcoin 20-80
# varia_bb = saida_BB["BB_UPPER"] - saida_300_passada
# saida_BB

# %%
# fig, ax = plt.subplots(1,1)
# fig.set_size_inches(18.5, 20.5)
# plt.plot(df_normalizada,label='dif_300')
# # plt.plot(saida_BB["BB_UPPER"] - saida_300_passada,label='BB')
# # plt.plot(saida_BB["BB_LOWER"] - saida_300_passada,label='BB')
# # plt.plot(varia_bb * 2, label='BB')

# plt.show()

# %%
# def cre_map(df_normalizada):
#     max_v = 10000
#     min_ = -10000
#     def c_map(x):
#         pass
# #     df_normalizada.max()
# #     df_normalizada.min()

# %%
# def filt_fun(x):
#     r_saida = (x > 0) & (x <1000)
#     return r_saida

# df_normalizada_filtered = df_normalizada.mask(filt_fun)
# # df_normalizada_filtered.dropna()
# df_normalizada_filtered

# %%
# df_normalizada_filtered

# %%
# inicio = 100
# fim = 10000 + inicio

# fig, ax = plt.subplots()
# fig.set_size_inches(18.5, 10.5)




# # saida_saida_30 = TA.EMA(df_sadida, 30)
# # saida_saida_30.head()

# plt.plot(df_sadida[-fim:-inicio],label='dif_300')
# # plt.plot(saida_saida_30[-fim:-inicio],label='dif_300_3')

# %%
# df_sadida

# %%
# df_normalizada_filtered.index.values[-fim:-inicio]

# %%
# df_ultimos_30 = df_criado
# df_ultimos_30

# %%
# def estrategia(df_ultimos_30):

#     df_ultimos_30["t_ema_100"]= TA.EMA(df_ultimos_30, 100)
#     df_ultimos_30["t_ema_30"]= TA.EMA(df_ultimos_30, 30)

#     r_vari_positiva = df_ultimos_30["t_ema_100"].iloc[-1] - df_ultimos_30["t_ema_100"].iloc[-2] >0

#     r_preco_bom = df_ultimos_30["t_ema_30"].iloc[-1] < df_ultimos_30["Close"].iloc[-1]

#     r_libera_compra = r_vari_positiva + r_preco_bom
    
# #     vl_saida = df_ultimos_30["t_ema_100"].iloc[-1]
#     deu_ruim = df_ultimos_30["t_ema_100"].iloc[-1]
#     return r_libera_compra, deu_ruim, df_ultimos_30["t_ema_100"].iloc[-1]

# %%
# def get_os_iniciais(quantidade):
#     return df_criado[-quantidade:]

# %%
# def constori_gerador_dados(df_criado):

#     return gerador

# %%
# class Mercador():
#     def __init__(self, qnt_inicial):
#         self.quantidade = qnt_inicial
#         self.btc = 0
#         self.ls_negociado = []
        
        
#     def compra(self, negociacao, preco):
#         r_ja_comprado = self.btc > 0
#         if not r_ja_comprado:
#             self.quantidade = self.quantidade - negociacao
#             self.btc = negociacao/preco * 1# (1 - 0.70/100)
#             print("compro uma vez pelo ",preco," a quantidade de ",self.btc )
#             plt.plot(self.ls_negociado)
#             plt.show()
#         return r_ja_comprado
    
#     def venda(self, negociacao):
#         r_tem_pra_vender = self.btc > 0
#         if r_tem_pra_vender:
#             self.quantidade = self.quantidade + self.btc * negociacao * 1 #(1- 0.7/100)
            

#             self.ls_negociado.append(self.quantidade)
#             print("vendeu a quantidade de ",self.btc, " pelo valor de ", negociacao)
#             plt.plot(self.ls_negociado)
#             plt.show()
            
#             self.btc = 0
            
#         return r_tem_pra_vender

# %%
# def adicionand_ge(saida, df_ultimos_30 ):
#     dict_saida = {"Date":saida[0],
#                   "fim":saida[1]["fim"],
#                   "Open":saida[1]["Open"], 
#                   "Close":saida[1]["Close"], 
#                   "Volume":saida[1]["Volume"],
#                   "High":saida[1]["High"],
#                   "Low":saida[1]["Low"]} 
    
    
#     df_ultimos_30 =df_ultimos_30.drop(df_ultimos_30.index[0])
#     return df_ultimos_30.append(dict_saida, ignore_index=True)

# %%
# mercador = Mercador(100)
# df_ultimos_30 = get_os_iniciais(150)

# gera = cria_gerador(df_criado)

# %%
# i=0
# r_ja_comprado= False
# for saida in gera:
#         # for valor in gera:
#     #     print(saida[0])
#     # saida = next(gera)
#     df_ultimos_30 = adicionand_ge(saida, df_ultimos_30)

#     r_compra, v_liquida, v_lucro = estrategia(df_ultimos_30)

#     valor_atual = saida[1]["Close"]

    

#     if r_ja_comprado:
#         if valor_atual < v_liquida:
#             mercador.venda(valor_atual)

#         if valor_atual > v_lucro:
#             mercador.venda(valor_atual)
    
#     if r_compra:
#         r_ja_comprado = mercador.compra(10, valor_atual )
        

        
# print(valor_atual, r_compra, v_liquida, v_lucro )

# %%
# saida[1]

# %%
# saida[1]["Close"] > v_lucro

# %%
# type(saida)

# %%
# df_ultimos_30.iloc[-1]

# %%
# mpf.plot(df_criado[len(df_criado)-100:len(df_criado)],type='candle',volume=True)
# mpf.plot(saida)

# %%
# mpf.plot(df_criado,type='candle',volume=True)

# %%
# from finta import TA

# %%
# TA.SMA(df_criado, 42)

# %%
# TA.MACD(df_criado,12,26)

# %%
# ma = TA.MACD(df_criado,10,40)

# %%
# print(ma.head(100))

# %%
# TA.MOM(df_criado)

# %%
# TA.SMA(df_criado,10)

# %%
# TA.SMA(df_criado,20)

# %%
# TA.EMA(df_criado, 10)
# TA.EMA(df_criado, 30)

# %%
# TA.PIVOT_FIB(df_criado)

# %%
# r_comprar = r_cruzou_media_subindo + r_var_mac_positiva

# %%
# class Operacoes:
#     def __init__(self, qnt_compra_pedida_moeda,preco_tick, tipo ):
#         self.dic_operaca = {"qnt_moeda": qnt_compra_pedida_moeda, 
#                             "v_negociado":preco_tick,
#                             "t_operaca": tipo}

# %%
# https://github.com/peerchemist/finta
